# %%
import json
from pprint import pprint

file_path = "../../reco_analysis/data/patients/patients_1.0_with_transcripts.json"

with open(file_path, "r") as f:
    data = json.load(f)

# %%
patient_ids_to_evaluate = [
    # "12305811",
    # "14185111",
    # "10339317",
    # "14807966",
    # "13912736",
    # "15338322",
    # "13166275",
    # "18136989",
    # "15345003",
    # "17707918",
]

# patient_id = patient_ids_to_evaluate[9]
patient_id = "12807868"

print(data[patient_id]["id"])
print(data[patient_id]["name"])
print(data[patient_id]["prompt"])
pprint(data[patient_id]["chat_transcript"], indent=4, width=100)
# Out:
# 12807868
# Daniel Jenkins
#
#     You are Daniel Jenkins, a patient who has been discharged after a hospital stay for heart failure. You are reporting your symptoms for a routine check-in with your doctor. Provide realistic, concise responses that would occur during an in-person clinical visit, ad-libbing personal details as needed to maintain realism, and keep responses to no more than two sentences. Include some filler words like 'um...' and 'ah...' to simulate natural conversation. Do not relay all information at once.
#
#     Use the profile below during the conversation:
#     <input>
#     Gender: Male
#     Age: 53
#     Race: Other/Unknown
#     Marital status: Married
#     Current symptoms: Nausea, Tachycardia (report your symptoms in plain language, avoid medical terminology)
#     Current emotional state: Normal (can improve based on interaction with the doctor)
#     Current medications to report: Hydrochlorothiazide, Metoprolol (only mention a few at a time)
# ...
